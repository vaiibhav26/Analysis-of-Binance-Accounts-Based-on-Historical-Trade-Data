# %%
import pandas as pd
import json

# %%
# Load the dataset
file_path = 'TRADES_CopyTr_90D_ROI.csv'
df = pd.read_csv(file_path)

# Drop rows with missing Trade_History for this analysis
df_clean = df.dropna(subset=['Trade_History']).copy()

# Inspect a few raw entries to identify formatting issues
raw_entries = df_clean['Trade_History'].head(5)

# Print out raw entries for inspection
for index, entry in enumerate(raw_entries):
    print(f"Entry {index}:\n{entry}\n")
# Out:
# Entry 0:
# [{'time': 1718899656000, 'symbol': 'SOLUSDT', 'side': 'BUY', 'price': 132.537, 'fee': -0.9940275, 'feeAsset': 'USDT', 'quantity': 1988.055, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'SOL', 'qty': 15.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718899618000, 'symbol': 'DOGEUSDT', 'side': 'BUY', 'price': 0.12182, 'fee': -0.27979617, 'feeAsset': 'USDT', 'quantity': 1398.98088, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'DOGE', 'qty': 11484.0, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718899618000, 'symbol': 'DOGEUSDT', 'side': 'BUY', 'price': 0.12182, 'fee': -0.03949404, 'feeAsset': 'USDT', 'quantity': 197.47022, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'DOGE', 'qty': 1621.0, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718899616000, 'symbol': 'DOGEUSDT', 'side': 'BUY', 'price': 0.12182, 'fee': -0.00828375, 'feeAsset': 'USDT', 'quantity': 16.56752, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'DOGE', 'qty': 136.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718899616000, 'symbol': 'DOGEUSDT', 'side': 'BUY', 'price': 0.12182, 'fee': -0.04610887, 'feeAsset': 'USDT', 'quantity': 92.21774, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'DOGE', 'qty': 757.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718899616000, 'symbol': 'DOGEUSDT', 'side': 'BUY', 'price': 0.12182, 'fee': -0.12571824, 'feeAsset': 'USDT', 'quantity': 251.43648, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'DOGE', 'qty': 2064.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718899616000, 'symbol': 'DOGEUSDT', 'side': 'BUY', 'price': 0.12182, 'fee': -0.02180578, 'feeAsset': 'USDT', 'quantity': 43.61156, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'DOGE', 'qty': 358.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718899607000, 'symbol': 'SOLUSDT', 'side': 'BUY', 'price': 132.585, 'fee': -0.159102, 'feeAsset': 'USDT', 'quantity': 795.51, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'SOL', 'qty': 6.0, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718899607000, 'symbol': 'SOLUSDT', 'side': 'BUY', 'price': 132.585, 'fee': -0.5966325, 'feeAsset': 'USDT', 'quantity': 1193.265, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'SOL', 'qty': 9.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718889684000, 'symbol': 'FILUSDT', 'side': 'BUY', 'price': 4.454, 'fee': -0.3485255, 'feeAsset': 'USDT', 'quantity': 697.051, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'FIL', 'qty': 156.5, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718889684000, 'symbol': 'FILUSDT', 'side': 'BUY', 'price': 4.454, 'fee': -0.0031178, 'feeAsset': 'USDT', 'quantity': 6.2356, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'FIL', 'qty': 1.4, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718889684000, 'symbol': 'FILUSDT', 'side': 'BUY', 'price': 4.454, 'fee': -0.13361999, 'feeAsset': 'USDT', 'quantity': 267.24, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'FIL', 'qty': 60.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718889684000, 'symbol': 'FILUSDT', 'side': 'BUY', 'price': 4.454, 'fee': -0.5146597, 'feeAsset': 'USDT', 'quantity': 1029.3194, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'FIL', 'qty': 231.1, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718889588000, 'symbol': 'FILUSDT', 'side': 'BUY', 'price': 4.471, 'fee': -0.16565055, 'feeAsset': 'USDT', 'quantity': 331.3011, 'quant ...
#
# Entry 1:
# [{'time': 1718980078000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.344, 'fee': -0.138944, 'feeAsset': 'USDT', 'quantity': 277.888, 'quantityAsset': 'USDT', 'realizedProfit': 7.02899999, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 52.0, 'positionSide': 'BOTH', 'activeBuy': False}, {'time': 1718976178000, 'symbol': 'NEARUSDT', 'side': 'BUY', 'price': 5.183, 'fee': -0.046647, 'feeAsset': 'USDT', 'quantity': 93.294, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 18.0, 'positionSide': 'BOTH', 'activeBuy': True}, {'time': 1718974114000, 'symbol': 'NEARUSDT', 'side': 'BUY', 'price': 5.212, 'fee': -0.00521199, 'feeAsset': 'USDT', 'quantity': 10.424, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 2.0, 'positionSide': 'BOTH', 'activeBuy': True}, {'time': 1718974114000, 'symbol': 'NEARUSDT', 'side': 'BUY', 'price': 5.212, 'fee': -0.033878, 'feeAsset': 'USDT', 'quantity': 67.756, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 13.0, 'positionSide': 'BOTH', 'activeBuy': True}, {'time': 1718974114000, 'symbol': 'NEARUSDT', 'side': 'BUY', 'price': 5.212, 'fee': -0.00521199, 'feeAsset': 'USDT', 'quantity': 10.424, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 2.0, 'positionSide': 'BOTH', 'activeBuy': True}, {'time': 1718973525000, 'symbol': 'NEARUSDT', 'side': 'BUY', 'price': 5.233, 'fee': -0.0177922, 'feeAsset': 'USDT', 'quantity': 88.961, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 17.0, 'positionSide': 'BOTH', 'activeBuy': False}, {'time': 1718963384000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.0516288, 'feeAsset': 'USDT', 'quantity': 258.144, 'quantityAsset': 'USDT', 'realizedProfit': 6.2796923, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 48.0, 'positionSide': 'BOTH', 'activeBuy': True}, {'time': 1718963381000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.00860479, 'feeAsset': 'USDT', 'quantity': 43.024, 'quantityAsset': 'USDT', 'realizedProfit': 1.04661538, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 8.0, 'positionSide': 'BOTH', 'activeBuy': True}, {'time': 1718963381000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.00107559, 'feeAsset': 'USDT', 'quantity': 5.378, 'quantityAsset': 'USDT', 'realizedProfit': 0.13082692, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 1.0, 'positionSide': 'BOTH', 'activeBuy': True}, {'time': 1718963380000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.010756, 'feeAsset': 'USDT', 'quantity': 21.512, 'quantityAsset': 'USDT', 'realizedProfit': 0.52330769, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 4.0, 'positionSide': 'BOTH', 'activeBuy': False}, {'time': 1718963380000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.06722499, 'feeAsset': 'USDT', 'quantity': 134.45, 'quantityAsset': 'USDT', 'realizedProfit': 3.27067307, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 25.0, 'positionSide': 'BOTH', 'activeBuy': False}, {'time': 1718963380000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.024201, 'feeAsset': 'USDT', 'quantity': 48.402, 'quantityAsset': 'USDT', 'realizedProfit': 1.1774423, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 9.0, 'positionSide': 'BOTH', 'activeBuy': False}, {'time': 1718963380000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.002689, 'feeAsset': 'USDT', 'quantity': 5.378, 'quantityAsset': 'USDT', 'realizedProfit': 0.13082692, 'realizedProfitAsset': 'USDT', 'baseAsset': 'NEAR', 'qty': 1.0, 'positionSide': 'BOTH', 'activeBuy': False}, {'time': 1718963380000, 'symbol': 'NEARUSDT', 'side': 'SELL', 'price': 5.378, 'fee': -0.16134, 'feeAsset': 'USDT', 'quantity': 322 ...
#
# Entry 2:
# [{'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.28, 'fee': -0.16378944, 'feeAsset': 'USDT', 'quantity': 327.57888, 'quantityAsset': 'USDT', 'realizedProfit': 1.78848, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.096, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.28, 'fee': -0.0255921, 'feeAsset': 'USDT', 'quantity': 51.1842, 'quantityAsset': 'USDT', 'realizedProfit': 0.27945, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.015, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.31, 'fee': -2.84074807, 'feeAsset': 'USDT', 'quantity': 5681.49615, 'quantityAsset': 'USDT', 'realizedProfit': 31.0689, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 1.665, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.32, 'fee': -0.0255924, 'feeAsset': 'USDT', 'quantity': 51.1848, 'quantityAsset': 'USDT', 'realizedProfit': 0.28005, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.015, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.32, 'fee': -0.89914632, 'feeAsset': 'USDT', 'quantity': 1798.29264, 'quantityAsset': 'USDT', 'realizedProfit': 9.83909, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.527, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.33, 'fee': -0.01023699, 'feeAsset': 'USDT', 'quantity': 20.47398, 'quantityAsset': 'USDT', 'realizedProfit': 0.11208, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.006, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.35, 'fee': -0.01194322, 'feeAsset': 'USDT', 'quantity': 23.88645, 'quantityAsset': 'USDT', 'realizedProfit': 0.1309, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.007, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.35, 'fee': -0.0614223, 'feeAsset': 'USDT', 'quantity': 122.8446, 'quantityAsset': 'USDT', 'realizedProfit': 0.6732, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.036, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.36, 'fee': -0.0255927, 'feeAsset': 'USDT', 'quantity': 51.1854, 'quantityAsset': 'USDT', 'realizedProfit': 0.28065, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.015, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718677164000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3412.38, 'fee': -0.93499212, 'feeAsset': 'USDT', 'quantity': 1869.98424, 'quantityAsset': 'USDT', 'realizedProfit': 10.26404, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.548, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718676485000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3393.65, 'fee': -2.44851847, 'feeAsset': 'USDT', 'quantity': 4897.03695, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 1.443, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718676485000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3393.65, 'fee': -0.02375555, 'feeAsset': 'USDT', 'quantity': 47.5111, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.014, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718676485000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3393.65, 'fee': -2.49942322, 'feeAsset': 'USDT', 'quantity': 4998.84645, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 1.473, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718395574000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3410.9 ...
#
# Entry 3:
# [{'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.79, 'fee': -2.32607562, 'feeAsset': 'USDT', 'quantity': 4652.15124, 'quantityAsset': 'USDT', 'realizedProfit': 15.30421084, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 1.356, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.79, 'fee': -0.01029237, 'feeAsset': 'USDT', 'quantity': 20.58474, 'quantityAsset': 'USDT', 'realizedProfit': 0.06771774, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.006, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.8, 'fee': -0.025731, 'feeAsset': 'USDT', 'quantity': 51.462, 'quantityAsset': 'USDT', 'realizedProfit': 0.16944436, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.015, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.82, 'fee': -0.02401574, 'feeAsset': 'USDT', 'quantity': 48.03148, 'quantityAsset': 'USDT', 'realizedProfit': 0.15842807, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.014, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.83, 'fee': -0.0120079, 'feeAsset': 'USDT', 'quantity': 24.01581, 'quantityAsset': 'USDT', 'realizedProfit': 0.07928403, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.007, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.84, 'fee': -0.0257313, 'feeAsset': 'USDT', 'quantity': 51.4626, 'quantityAsset': 'USDT', 'realizedProfit': 0.17004436, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.015, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.86, 'fee': -0.24873735, 'feeAsset': 'USDT', 'quantity': 497.4747, 'quantityAsset': 'USDT', 'realizedProfit': 1.64666222, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.145, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.88, 'fee': -0.0257316, 'feeAsset': 'USDT', 'quantity': 51.4632, 'quantityAsset': 'USDT', 'realizedProfit': 0.17064436, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.015, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.89, 'fee': -2.5045497, 'feeAsset': 'USDT', 'quantity': 5009.0994, 'quantityAsset': 'USDT', 'realizedProfit': 16.62398512, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 1.46, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.89, 'fee': -4.58195359, 'feeAsset': 'USDT', 'quantity': 9163.90719, 'quantityAsset': 'USDT', 'realizedProfit': 30.41278374, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 2.671, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.89, 'fee': -1.2505594, 'feeAsset': 'USDT', 'quantity': 2501.11881, 'quantityAsset': 'USDT', 'realizedProfit': 8.30060627, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.729, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.89, 'fee': -1.7995018, 'feeAsset': 'USDT', 'quantity': 3599.00361, 'quantityAsset': 'USDT', 'realizedProfit': 11.94421945, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 1.049, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718678214000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3430.89, 'fee': -0.09949581, 'feeAsset': 'USDT', 'quantity': 198.99162, 'quantityAsset': 'USDT', 'realizedProfit': 0.66040488, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.058, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 171867821400 ...
#
# Entry 4:
# [{'time': 1718979615000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3501.6, 'fee': -0.5304924, 'feeAsset': 'USDT', 'quantity': 1060.9848, 'quantityAsset': 'USDT', 'realizedProfit': 6.72054, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.303, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718979615000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3501.6, 'fee': -0.0122556, 'feeAsset': 'USDT', 'quantity': 24.5112, 'quantityAsset': 'USDT', 'realizedProfit': 0.15526, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.007, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718979615000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3501.6, 'fee': -0.332652, 'feeAsset': 'USDT', 'quantity': 665.304, 'quantityAsset': 'USDT', 'realizedProfit': 4.2142, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.19, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718979038000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3480.51, 'fee': -0.13399963, 'feeAsset': 'USDT', 'quantity': 267.99927, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.077, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718979038000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3480.51, 'fee': -0.01218178, 'feeAsset': 'USDT', 'quantity': 24.36357, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.007, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718979038000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3480.51, 'fee': -0.01566229, 'feeAsset': 'USDT', 'quantity': 31.32459, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.009, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718979038000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3480.51, 'fee': -0.01218178, 'feeAsset': 'USDT', 'quantity': 24.36357, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.007, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718979035000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3479.62, 'fee': -0.173981, 'feeAsset': 'USDT', 'quantity': 347.962, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.1, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718979033000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3479.02, 'fee': -0.173951, 'feeAsset': 'USDT', 'quantity': 347.902, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.1, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718979031000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3478.68, 'fee': -0.173934, 'feeAsset': 'USDT', 'quantity': 347.868, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.1, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718979029000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3479.27, 'fee': -0.1739635, 'feeAsset': 'USDT', 'quantity': 347.927, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.1, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718813264000, 'symbol': 'ETHUSDT', 'side': 'SELL', 'price': 3533.22, 'fee': -0.883305, 'feeAsset': 'USDT', 'quantity': 1766.61, 'quantityAsset': 'USDT', 'realizedProfit': 8.585, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.5, 'positionSide': 'LONG', 'activeBuy': False}, {'time': 1718807489000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3515.01, 'fee': -0.1757505, 'feeAsset': 'USDT', 'quantity': 351.501, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'ETH', 'qty': 0.1, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718807487000, 'symbol': 'ETHUSDT', 'side': 'BUY', 'price': 3515.89, 'fee': -0.1757945, 'feeAsset': 'USDT', 'quantity': 351.589, 'quantityAsset' ...

# %%
def parse_json(trade_history):
    try:
        # Fix JSON formatting issues
        trade_history = trade_history.replace("'", '"')  # Replace single quotes with double quotes
        trade_history = trade_history.replace("None", "null")  # Replace Python None with JSON null
        trade_history = trade_history.replace("True", "true").replace("False", "false")  # Replace Python booleans
        # Ensure there are no trailing commas
        trade_history = trade_history.replace(",}", "}").replace(",]", "]")

        # Parse the JSON string
        return json.loads(trade_history)
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e} in entry: {trade_history[:100]}...")
        return None

# %%
# Apply parsing to each entry
df_clean['Parsed_Trade_History'] = df_clean['Trade_History'].apply(parse_json)

# %%
# Check for any entries that couldn't be parsed
unparsed_entries = df_clean[df_clean['Parsed_Trade_History'].isnull()]

# %%
# Display the number of unparsed entries
num_unparsed_entries = len(unparsed_entries)

# %%
if not df_clean['Parsed_Trade_History'].dropna().empty:
    sample_trade_history = df_clean['Parsed_Trade_History'].dropna().iloc[0]
else:
    sample_trade_history = "No entries were successfully parsed."

num_unparsed_entries, sample_trade_history
# Out:
# (0,
#  [{'time': 1718899656000,
#    'symbol': 'SOLUSDT',
#    'side': 'BUY',
#    'price': 132.537,
#    'fee': -0.9940275,
#    'feeAsset': 'USDT',
#    'quantity': 1988.055,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'SOL',
#    'qty': 15.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718899618000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12182,
#    'fee': -0.27979617,
#    'feeAsset': 'USDT',
#    'quantity': 1398.98088,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 11484.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718899618000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12182,
#    'fee': -0.03949404,
#    'feeAsset': 'USDT',
#    'quantity': 197.47022,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 1621.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718899616000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12182,
#    'fee': -0.00828375,
#    'feeAsset': 'USDT',
#    'quantity': 16.56752,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 136.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718899616000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12182,
#    'fee': -0.04610887,
#    'feeAsset': 'USDT',
#    'quantity': 92.21774,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 757.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718899616000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12182,
#    'fee': -0.12571824,
#    'feeAsset': 'USDT',
#    'quantity': 251.43648,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 2064.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718899616000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12182,
#    'fee': -0.02180578,
#    'feeAsset': 'USDT',
#    'quantity': 43.61156,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 358.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718899607000,
#    'symbol': 'SOLUSDT',
#    'side': 'BUY',
#    'price': 132.585,
#    'fee': -0.159102,
#    'feeAsset': 'USDT',
#    'quantity': 795.51,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'SOL',
#    'qty': 6.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718899607000,
#    'symbol': 'SOLUSDT',
#    'side': 'BUY',
#    'price': 132.585,
#    'fee': -0.5966325,
#    'feeAsset': 'USDT',
#    'quantity': 1193.265,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'SOL',
#    'qty': 9.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889684000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.454,
#    'fee': -0.3485255,
#    'feeAsset': 'USDT',
#    'quantity': 697.051,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 156.5,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889684000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.454,
#    'fee': -0.0031178,
#    'feeAsset': 'USDT',
#    'quantity': 6.2356,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 1.4,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889684000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.454,
#    'fee': -0.13361999,
#    'feeAsset': 'USDT',
#    'quantity': 267.24,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 60.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889684000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.454,
#    'fee': -0.5146597,
#    'feeAsset': 'USDT',
#    'quantity': 1029.3194,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 231.1,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889588000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.471,
#    'fee': -0.16565055,
#    'feeAsset': 'USDT',
#    'quantity': 331.3011,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 74.1,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889588000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.471,
#    'fee': -0.13413,
#    'feeAsset': 'USDT',
#    'quantity': 268.26,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 60.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889588000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.471,
#    'fee': -0.67065,
#    'feeAsset': 'USDT',
#    'quantity': 1341.3,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 300.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718889588000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.471,
#    'fee': -0.0295086,
#    'feeAsset': 'USDT',
#    'quantity': 59.0172,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 13.2,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.525,
#    'fee': -0.01925212,
#    'feeAsset': 'USDT',
#    'quantity': 38.50425,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.33256281,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.57,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.525,
#    'fee': -0.100062,
#    'feeAsset': 'USDT',
#    'quantity': 200.124,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 6.92593156,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.525,
#    'fee': -0.25751249,
#    'feeAsset': 'USDT',
#    'quantity': 515.025,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 17.82408858,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 21.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.526,
#    'fee': -0.10006608,
#    'feeAsset': 'USDT',
#    'quantity': 200.13216,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 6.93409156,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.526,
#    'fee': -0.20000953,
#    'feeAsset': 'USDT',
#    'quantity': 400.01906,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 13.85968547,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 16.31,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.526,
#    'fee': -0.10006608,
#    'feeAsset': 'USDT',
#    'quantity': 200.13216,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 6.93409156,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.526,
#    'fee': -0.3347799,
#    'feeAsset': 'USDT',
#    'quantity': 669.5598,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 23.19861516,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 27.3,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.526,
#    'fee': -0.01508349,
#    'feeAsset': 'USDT',
#    'quantity': 30.16698,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.04521233,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.23,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.526,
#    'fee': -0.01508349,
#    'feeAsset': 'USDT',
#    'quantity': 30.16698,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.04521233,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.23,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.10007016,
#    'feeAsset': 'USDT',
#    'quantity': 200.14032,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 6.94225156,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.10007016,
#    'feeAsset': 'USDT',
#    'quantity': 200.14032,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 6.94225156,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.20001768,
#    'feeAsset': 'USDT',
#    'quantity': 400.03537,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 13.87599547,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 16.31,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.02930976,
#    'feeAsset': 'USDT',
#    'quantity': 58.61953,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.03333103,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 2.39,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.03544151,
#    'feeAsset': 'USDT',
#    'quantity': 70.88303,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.45871409,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 2.89,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.03544151,
#    'feeAsset': 'USDT',
#    'quantity': 70.88303,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.45871409,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 2.89,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.01410302,
#    'feeAsset': 'USDT',
#    'quantity': 28.20605,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.97838104,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.15,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.2918713,
#    'feeAsset': 'USDT',
#    'quantity': 583.7426,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 20.24823373,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 23.8,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.16273664,
#    'feeAsset': 'USDT',
#    'quantity': 325.47329,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 11.28966645,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 13.27,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.01005607,
#    'feeAsset': 'USDT',
#    'quantity': 20.11214,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.69762822,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 0.82,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.527,
#    'fee': -0.39059247,
#    'feeAsset': 'USDT',
#    'quantity': 781.18495,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 27.09690102,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 31.85,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.528,
#    'fee': -0.10007424,
#    'feeAsset': 'USDT',
#    'quantity': 200.14848,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 6.95041156,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.528,
#    'fee': -0.10007424,
#    'feeAsset': 'USDT',
#    'quantity': 200.14848,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 6.95041156,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.528,
#    'fee': -0.01508472,
#    'feeAsset': 'USDT',
#    'quantity': 30.16944,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.04767233,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.23,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.528,
#    'fee': -0.14913024,
#    'feeAsset': 'USDT',
#    'quantity': 298.26048,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 10.35747605,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 12.16,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.528,
#    'fee': -0.3348072,
#    'feeAsset': 'USDT',
#    'quantity': 669.6144,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 23.25321516,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 27.3,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.528,
#    'fee': -0.0741972,
#    'feeAsset': 'USDT',
#    'quantity': 148.3944,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 5.15318504,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 6.05,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.529,
#    'fee': -0.01508533,
#    'feeAsset': 'USDT',
#    'quantity': 30.17067,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.04890233,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.23,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.529,
#    'fee': -0.06770004,
#    'feeAsset': 'USDT',
#    'quantity': 135.40008,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 4.707269,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 5.52,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718874124000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.529,
#    'fee': -0.0662283,
#    'feeAsset': 'USDT',
#    'quantity': 132.4566,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 4.60493706,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 5.4,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718873009000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.20511672,
#    'feeAsset': 'USDT',
#    'quantity': 1025.5836,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 225.8,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718873009000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.02761536,
#    'feeAsset': 'USDT',
#    'quantity': 138.0768,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 30.4,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.06813,
#    'feeAsset': 'USDT',
#    'quantity': 136.26,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 30.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.2843292,
#    'feeAsset': 'USDT',
#    'quantity': 568.6584,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 125.2,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.0111279,
#    'feeAsset': 'USDT',
#    'quantity': 22.2558,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 4.9,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.0084027,
#    'feeAsset': 'USDT',
#    'quantity': 16.8054,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 3.7,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.7975752,
#    'feeAsset': 'USDT',
#    'quantity': 1595.1504,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 351.2,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.0027252,
#    'feeAsset': 'USDT',
#    'quantity': 5.4504,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 1.2,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.14261879,
#    'feeAsset': 'USDT',
#    'quantity': 285.2376,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 62.8,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.0233913,
#    'feeAsset': 'USDT',
#    'quantity': 46.7826,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 10.3,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.0036336,
#    'feeAsset': 'USDT',
#    'quantity': 7.2672,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 1.6,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718873005000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.542,
#    'fee': -0.07607849,
#    'feeAsset': 'USDT',
#    'quantity': 152.157,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 33.5,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.622,
#    'fee': -0.04222673,
#    'feeAsset': 'USDT',
#    'quantity': 84.45346,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 3.2439778,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 3.43,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.622,
#    'fee': -0.20029997,
#    'feeAsset': 'USDT',
#    'quantity': 400.59994,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 15.38761482,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 16.27,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.622,
#    'fee': -0.677105,
#    'feeAsset': 'USDT',
#    'quantity': 1354.21,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 52.01713678,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 55.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.622,
#    'fee': -0.1908205,
#    'feeAsset': 'USDT',
#    'quantity': 381.641,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 14.65937491,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 15.5,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.622,
#    'fee': -0.01009502,
#    'feeAsset': 'USDT',
#    'quantity': 20.19004,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.77552822,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 0.82,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.622,
#    'fee': -0.01501942,
#    'feeAsset': 'USDT',
#    'quantity': 30.03884,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.15383467,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.22,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.622,
#    'fee': -0.01501942,
#    'feeAsset': 'USDT',
#    'quantity': 30.03884,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.15383467,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.22,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.623,
#    'fee': -0.31468194,
#    'feeAsset': 'USDT',
#    'quantity': 629.36388,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 24.19934211,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 25.56,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.623,
#    'fee': -0.2003081,
#    'feeAsset': 'USDT',
#    'quantity': 400.61621,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 15.40388482,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 16.27,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.623,
#    'fee': -0.30003125,
#    'feeAsset': 'USDT',
#    'quantity': 600.06251,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 23.07269042,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 24.37,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.623,
#    'fee': -0.10021561,
#    'feeAsset': 'USDT',
#    'quantity': 200.43122,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 7.70667624,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.14,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.623,
#    'fee': -0.10021561,
#    'feeAsset': 'USDT',
#    'quantity': 200.43122,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 7.70667624,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.14,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.623,
#    'fee': -0.36343548,
#    'feeAsset': 'USDT',
#    'quantity': 726.87096,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 27.94853595,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 29.52,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.14183424,
#    'feeAsset': 'USDT',
#    'quantity': 283.66848,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 10.91826574,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 11.52,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.01058832,
#    'feeAsset': 'USDT',
#    'quantity': 21.17664,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.81507886,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 0.86,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.01058832,
#    'feeAsset': 'USDT',
#    'quantity': 21.17664,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.81507886,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 0.86,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.01502064,
#    'feeAsset': 'USDT',
#    'quantity': 30.04128,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.15627467,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.22,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.10021968,
#    'feeAsset': 'USDT',
#    'quantity': 200.43936,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 7.71481624,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.14,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.10021968,
#    'feeAsset': 'USDT',
#    'quantity': 200.43936,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 7.71481624,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 8.14,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.03779784,
#    'feeAsset': 'USDT',
#    'quantity': 75.59568,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.90964199,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 3.07,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.3078,
#    'feeAsset': 'USDT',
#    'quantity': 615.6,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 23.69415308,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 25.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718868187000,
#    'symbol': 'ETCUSDT',
#    'side': 'SELL',
#    'price': 24.624,
#    'fee': -0.05860512,
#    'feeAsset': 'USDT',
#    'quantity': 117.21024,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 4.51136674,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 4.76,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718675516000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.359,
#    'fee': -0.08478255,
#    'feeAsset': 'USDT',
#    'quantity': 169.5651,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 38.9,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718675516000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.359,
#    'fee': -0.13077,
#    'feeAsset': 'USDT',
#    'quantity': 261.54,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 60.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718675516000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.359,
#    'fee': -0.065385,
#    'feeAsset': 'USDT',
#    'quantity': 130.77,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 30.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718675516000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.359,
#    'fee': -0.33760455,
#    'feeAsset': 'USDT',
#    'quantity': 675.2091,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 154.9,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718675516000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.359,
#    'fee': -0.3814125,
#    'feeAsset': 'USDT',
#    'quantity': 762.825,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 175.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674682000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.647,
#    'fee': -0.28263054,
#    'feeAsset': 'USDT',
#    'quantity': 1413.1527,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 304.1,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718674682000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.647,
#    'fee': -0.08987298,
#    'feeAsset': 'USDT',
#    'quantity': 449.3649,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 96.7,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718674682000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.647,
#    'fee': -0.069705,
#    'feeAsset': 'USDT',
#    'quantity': 139.41,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 30.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674515000,
#    'symbol': 'SOLUSDT',
#    'side': 'BUY',
#    'price': 137.027,
#    'fee': -0.7536485,
#    'feeAsset': 'USDT',
#    'quantity': 1507.297,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'SOL',
#    'qty': 11.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674515000,
#    'symbol': 'SOLUSDT',
#    'side': 'BUY',
#    'price': 137.027,
#    'fee': -0.2055405,
#    'feeAsset': 'USDT',
#    'quantity': 411.081,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'SOL',
#    'qty': 3.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674494000,
#    'symbol': 'SOLUSDT',
#    'side': 'BUY',
#    'price': 137.246,
#    'fee': -0.960722,
#    'feeAsset': 'USDT',
#    'quantity': 1921.444,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'SOL',
#    'qty': 14.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674446000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.642,
#    'fee': -0.1244056,
#    'feeAsset': 'USDT',
#    'quantity': 248.8112,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 53.6,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674446000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.642,
#    'fee': -0.4720914,
#    'feeAsset': 'USDT',
#    'quantity': 944.1828,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 203.4,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674446000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.642,
#    'fee': -0.0902869,
#    'feeAsset': 'USDT',
#    'quantity': 180.5738,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 38.9,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718674446000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.642,
#    'fee': -0.81235,
#    'feeAsset': 'USDT',
#    'quantity': 1624.7,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 350.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.23669883,
#    'feeAsset': 'USDT',
#    'quantity': 1183.49417,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 9437.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.0075246,
#    'feeAsset': 'USDT',
#    'quantity': 37.623,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 300.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.0025082,
#    'feeAsset': 'USDT',
#    'quantity': 12.541,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 100.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.00827705,
#    'feeAsset': 'USDT',
#    'quantity': 16.55412,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 132.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.05975786,
#    'feeAsset': 'USDT',
#    'quantity': 119.51573,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 953.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.0025082,
#    'feeAsset': 'USDT',
#    'quantity': 5.0164,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 40.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.01454756,
#    'feeAsset': 'USDT',
#    'quantity': 29.09512,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 232.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.01348157,
#    'feeAsset': 'USDT',
#    'quantity': 26.96315,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 215.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.00263361,
#    'feeAsset': 'USDT',
#    'quantity': 5.26722,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 42.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673423000,
#    'symbol': 'DOGEUSDT',
#    'side': 'BUY',
#    'price': 0.12541,
#    'fee': -0.78243299,
#    'feeAsset': 'USDT',
#    'quantity': 1564.86598,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'DOGE',
#    'qty': 12478.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673344000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.765,
#    'fee': -0.647087,
#    'feeAsset': 'USDT',
#    'quantity': 1294.174,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 271.6,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673344000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.765,
#    'fee': -0.099112,
#    'feeAsset': 'USDT',
#    'quantity': 198.224,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 41.6,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673344000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.765,
#    'fee': -0.071475,
#    'feeAsset': 'USDT',
#    'quantity': 142.95,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 30.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673344000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.765,
#    'fee': -0.064804,
#    'feeAsset': 'USDT',
#    'quantity': 129.608,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 27.2,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673344000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.765,
#    'fee': -0.05408275,
#    'feeAsset': 'USDT',
#    'quantity': 108.1655,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 22.7,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673344000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.765,
#    'fee': -0.0633745,
#    'feeAsset': 'USDT',
#    'quantity': 126.749,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 26.6,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673336000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.471,
#    'fee': -0.48533333,
#    'feeAsset': 'USDT',
#    'quantity': 2426.66669,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 103.39,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718673336000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.471,
#    'fee': -0.06360641,
#    'feeAsset': 'USDT',
#    'quantity': 127.21282,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 5.42,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673336000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.471,
#    'fee': -0.01502144,
#    'feeAsset': 'USDT',
#    'quantity': 30.04288,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.28,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673336000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.471,
#    'fee': -0.11535996,
#    'feeAsset': 'USDT',
#    'quantity': 230.71993,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 9.83,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718673336000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.471,
#    'fee': -0.09247574,
#    'feeAsset': 'USDT',
#    'quantity': 184.95148,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 7.88,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671587000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.801,
#    'fee': -0.02952615,
#    'feeAsset': 'USDT',
#    'quantity': 59.0523,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 12.3,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671587000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.801,
#    'fee': -0.09962075,
#    'feeAsset': 'USDT',
#    'quantity': 199.2415,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 41.5,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671587000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.801,
#    'fee': -0.51634755,
#    'feeAsset': 'USDT',
#    'quantity': 1032.6951,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 215.1,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671587000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.801,
#    'fee': -0.072015,
#    'feeAsset': 'USDT',
#    'quantity': 144.03,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 30.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671587000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.801,
#    'fee': -0.2822988,
#    'feeAsset': 'USDT',
#    'quantity': 564.5976,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 117.6,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671165000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.732,
#    'fee': -0.37216522,
#    'feeAsset': 'USDT',
#    'quantity': 1860.82612,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 78.41,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718671165000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.732,
#    'fee': -0.35455608,
#    'feeAsset': 'USDT',
#    'quantity': 1772.7804,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 74.7,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718671165000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.732,
#    'fee': -0.094928,
#    'feeAsset': 'USDT',
#    'quantity': 474.64,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 20.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718671145000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.745,
#    'fee': -0.87471831,
#    'feeAsset': 'USDT',
#    'quantity': 4373.59155,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 184.19,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718671145000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.745,
#    'fee': -0.00973545,
#    'feeAsset': 'USDT',
#    'quantity': 48.67725,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 2.05,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718671145000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.745,
#    'fee': -0.01507807,
#    'feeAsset': 'USDT',
#    'quantity': 30.15615,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.27,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671145000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.745,
#    'fee': -0.09296167,
#    'feeAsset': 'USDT',
#    'quantity': 185.92335,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 7.83,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671145000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.745,
#    'fee': -0.1700142,
#    'feeAsset': 'USDT',
#    'quantity': 340.0284,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 14.32,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671145000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.745,
#    'fee': -0.01080397,
#    'feeAsset': 'USDT',
#    'quantity': 21.60795,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 0.91,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671135000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.732,
#    'fee': -0.01506982,
#    'feeAsset': 'USDT',
#    'quantity': 30.13964,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.27,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671135000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.732,
#    'fee': -0.23732,
#    'feeAsset': 'USDT',
#    'quantity': 474.64,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 20.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671135000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.732,
#    'fee': -0.17893928,
#    'feeAsset': 'USDT',
#    'quantity': 357.87856,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 15.08,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671135000,
#    'symbol': 'ETCUSDT',
#    'side': 'BUY',
#    'price': 23.732,
#    'fee': -0.01447652,
#    'feeAsset': 'USDT',
#    'quantity': 28.95304,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETC',
#    'qty': 1.22,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.30440696,
#    'feeAsset': 'USDT',
#    'quantity': 1522.0348,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 314.6,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.0031447,
#    'feeAsset': 'USDT',
#    'quantity': 6.2894,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 1.3,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.0084665,
#    'feeAsset': 'USDT',
#    'quantity': 16.933,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 3.5,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.07257,
#    'feeAsset': 'USDT',
#    'quantity': 145.14,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 30.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.8413282,
#    'feeAsset': 'USDT',
#    'quantity': 1682.6564,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 347.8,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.14514,
#    'feeAsset': 'USDT',
#    'quantity': 290.28,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 60.0,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.0926477,
#    'feeAsset': 'USDT',
#    'quantity': 185.2954,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'FIL',
#    'qty': 38.3,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1718671123000,
#    'symbol': 'FILUSDT',
#    'side': 'BUY',
#    'price': 4.838,
#    'fee': -0.0232224,
#    'feeAsset': 'USDT',
#    'quantity': 46.4448,
#    'quantityAsset': 'USDT',
# ...
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.14,
#    'fee': -0.09464295,
#    'feeAsset': 'USDT',
#    'quantity': 189.2859,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.13587336,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.435,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.18,
#    'fee': -0.15731756,
#    'feeAsset': 'USDT',
#    'quantity': 314.63514,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 3.57888884,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.723,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.18,
#    'fee': -0.05113365,
#    'feeAsset': 'USDT',
#    'quantity': 102.2673,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.16326262,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.235,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.19,
#    'fee': -0.02001874,
#    'feeAsset': 'USDT',
#    'quantity': 40.03748,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.45632494,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.092,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.2,
#    'fee': -0.477632,
#    'feeAsset': 'USDT',
#    'quantity': 955.264,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 10.90926792,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 2.195,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.2,
#    'fee': -0.0650624,
#    'feeAsset': 'USDT',
#    'quantity': 130.1248,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.48604606,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.299,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.21,
#    'fee': -0.1088025,
#    'feeAsset': 'USDT',
#    'quantity': 217.605,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.49002686,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.5,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.22,
#    'fee': -0.19193202,
#    'feeAsset': 'USDT',
#    'quantity': 383.86404,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 4.40122738,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.882,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.23,
#    'fee': -0.02132627,
#    'feeAsset': 'USDT',
#    'quantity': 42.65254,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.49000526,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.098,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.24,
#    'fee': -0.10881,
#    'feeAsset': 'USDT',
#    'quantity': 217.62,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.50502686,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.5,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.24,
#    'fee': -0.10881,
#    'feeAsset': 'USDT',
#    'quantity': 217.62,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.50502686,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.5,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.26,
#    'fee': -0.19194966,
#    'feeAsset': 'USDT',
#    'quantity': 383.89932,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 4.43650738,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.882,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715776296000,
#    'symbol': 'BCHUSDT',
#    'side': 'SELL',
#    'price': 435.28,
#    'fee': -0.10163788,
#    'feeAsset': 'USDT',
#    'quantity': 203.27576,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 2.35837508,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.467,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715772276000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 424.66,
#    'fee': -0.1125349,
#    'feeAsset': 'USDT',
#    'quantity': 225.0698,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.53,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715772276000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 424.66,
#    'fee': -0.65801067,
#    'feeAsset': 'USDT',
#    'quantity': 1316.02134,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 3.099,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715772276000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 424.66,
#    'fee': -0.106165,
#    'feeAsset': 'USDT',
#    'quantity': 212.33,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.5,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715772276000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 424.66,
#    'fee': -0.09363753,
#    'feeAsset': 'USDT',
#    'quantity': 187.27506,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.441,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715772276000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 424.66,
#    'fee': -0.02951387,
#    'feeAsset': 'USDT',
#    'quantity': 59.02774,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.139,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.0972078,
#    'feeAsset': 'USDT',
#    'quantity': 194.4156,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.456,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.15625727,
#    'feeAsset': 'USDT',
#    'quantity': 312.51455,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.733,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.14581169,
#    'feeAsset': 'USDT',
#    'quantity': 291.6234,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.684,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.01065875,
#    'feeAsset': 'USDT',
#    'quantity': 21.3175,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.05,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.1065875,
#    'feeAsset': 'USDT',
#    'quantity': 213.175,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.5,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.0997659,
#    'feeAsset': 'USDT',
#    'quantity': 199.5318,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.468,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.22489962,
#    'feeAsset': 'USDT',
#    'quantity': 449.79925,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 1.055,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771666000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 426.35,
#    'fee': -0.1586022,
#    'feeAsset': 'USDT',
#    'quantity': 317.2044,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.744,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771105000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.59,
#    'fee': -0.30498464,
#    'feeAsset': 'USDT',
#    'quantity': 1524.92322,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 3.558,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715771100000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.59,
#    'fee': -0.00505736,
#    'feeAsset': 'USDT',
#    'quantity': 25.28681,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.059,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715771084000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.59,
#    'fee': -0.01500065,
#    'feeAsset': 'USDT',
#    'quantity': 30.0013,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.07,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771084000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.59,
#    'fee': -0.18879389,
#    'feeAsset': 'USDT',
#    'quantity': 377.58779,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.881,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771084000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.59,
#    'fee': -0.01050045,
#    'feeAsset': 'USDT',
#    'quantity': 21.00091,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.049,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715771084000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.59,
#    'fee': -0.01050045,
#    'feeAsset': 'USDT',
#    'quantity': 21.00091,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.049,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715766800000,
#    'symbol': 'ETHUSDT',
#    'side': 'SELL',
#    'price': 2929.52,
#    'fee': -1.19670892,
#    'feeAsset': 'USDT',
#    'quantity': 2393.41784,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 27.31816947,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETH',
#    'qty': 0.817,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715766800000,
#    'symbol': 'ETHUSDT',
#    'side': 'SELL',
#    'price': 2929.52,
#    'fee': -0.04980184,
#    'feeAsset': 'USDT',
#    'quantity': 99.60368,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.13686384,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETH',
#    'qty': 0.034,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715766800000,
#    'symbol': 'ETHUSDT',
#    'side': 'SELL',
#    'price': 2929.52,
#    'fee': -2.92952,
#    'feeAsset': 'USDT',
#    'quantity': 5859.04,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 66.87434389,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETH',
#    'qty': 2.0,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715766800000,
#    'symbol': 'ETHUSDT',
#    'side': 'SELL',
#    'price': 2929.52,
#    'fee': -0.06151992,
#    'feeAsset': 'USDT',
#    'quantity': 123.03984,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 1.40436122,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETH',
#    'qty': 0.042,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715766800000,
#    'symbol': 'ETHUSDT',
#    'side': 'SELL',
#    'price': 2929.52,
#    'fee': -0.01025332,
#    'feeAsset': 'USDT',
#    'quantity': 20.50664,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.2340602,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETH',
#    'qty': 0.007,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715766800000,
#    'symbol': 'ETHUSDT',
#    'side': 'SELL',
#    'price': 2929.52,
#    'fee': -0.04247804,
#    'feeAsset': 'USDT',
#    'quantity': 84.95608,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.96967798,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETH',
#    'qty': 0.029,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715766800000,
#    'symbol': 'ETHUSDT',
#    'side': 'SELL',
#    'price': 2929.52,
#    'fee': -0.99310728,
#    'feeAsset': 'USDT',
#    'quantity': 1986.21456,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 22.67040257,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'ETH',
#    'qty': 0.678,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715764056000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.09,
#    'fee': -0.15796521,
#    'feeAsset': 'USDT',
#    'quantity': 315.93042,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.738,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715764056000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.09,
#    'fee': -0.01134438,
#    'feeAsset': 'USDT',
#    'quantity': 22.68877,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.053,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715764056000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.09,
#    'fee': -0.01134438,
#    'feeAsset': 'USDT',
#    'quantity': 22.68877,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.053,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715764056000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 428.09,
#    'fee': -0.81915021,
#    'feeAsset': 'USDT',
#    'quantity': 1638.30043,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 3.827,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715762225000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 430.04,
#    'fee': -0.14690166,
#    'feeAsset': 'USDT',
#    'quantity': 734.50832,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 1.708,
#    'positionSide': 'LONG',
#    'activeBuy': False},
#   {'time': 1715762197000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 430.04,
#    'fee': -0.03246802,
#    'feeAsset': 'USDT',
#    'quantity': 64.93604,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.151,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715762197000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 430.04,
#    'fee': -0.01010594,
#    'feeAsset': 'USDT',
#    'quantity': 20.21188,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.047,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   {'time': 1715762197000,
#    'symbol': 'BCHUSDT',
#    'side': 'BUY',
#    'price': 430.04,
#    'fee': -0.0150514,
#    'feeAsset': 'USDT',
#    'quantity': 30.1028,
#    'quantityAsset': 'USDT',
#    'realizedProfit': 0.0,
#    'realizedProfitAsset': 'USDT',
#    'baseAsset': 'BCH',
#    'qty': 0.07,
#    'positionSide': 'LONG',
#    'activeBuy': True},
#   ...])

# %%
import numpy as np

def calculate_metrics(trade_history):
    # Initialize metrics
    total_pnl = 0
    total_investment = 0
    wins = 0
    total_trades = len(trade_history)
    returns = []  # To calculate Sharpe Ratio
    equity_curve = []  # To calculate Maximum Drawdown

    # Iterate through trades
    for trade in trade_history:
        pnl = trade.get('realizedProfit', 0)
        price = trade.get('price', 0)
        qty = trade.get('qty', 0)

        # Calculate PnL and total investment
        total_pnl += pnl
        investment = price * qty
        total_investment += investment

        # Calculate return for Sharpe Ratio
        if investment > 0:
            trade_return = pnl / investment
            returns.append(trade_return)

        # Track equity curve for Maximum Drawdown
        if equity_curve:
            equity_curve.append(equity_curve[-1] + pnl)
        else:
            equity_curve.append(pnl)

        # Count wins
        if pnl > 0:
            wins += 1

    # Calculate ROI
    roi = (total_pnl / total_investment) * 100 if total_investment != 0 else 0

    # Calculate Win Rate
    win_rate = (wins / total_trades) * 100 if total_trades != 0 else 0

    # Calculate Sharpe Ratio (using mean return and standard deviation of returns)
    mean_return = np.mean(returns) if returns else 0
    std_dev_return = np.std(returns) if returns else 1
    sharpe_ratio = (mean_return / std_dev_return) if std_dev_return != 0 else 0

    # Calculate Maximum Drawdown (MDD)
    peak = equity_curve[0] if equity_curve else 0
    max_drawdown = 0
    for equity in equity_curve:
        if equity > peak:
            peak = equity
        drawdown = (peak - equity) / peak if peak != 0 else 0
        if drawdown > max_drawdown:
            max_drawdown = drawdown

    return {
        'ROI': roi,
        'PnL': total_pnl,
        'Sharpe Ratio': sharpe_ratio,
        'Max Drawdown': max_drawdown * 100,
        'Win Rate': win_rate,
        'Win Positions': wins,
        'Total Positions': total_trades
    }

# Apply metrics calculation to each account
df_clean['Metrics'] = df_clean['Parsed_Trade_History'].apply(calculate_metrics)

# Display calculated metrics for the first account
df_clean[['Port_IDs', 'Metrics']].head()
# Out:
#               Port_IDs                                            Metrics
# 0  3925368433214965504  {'ROI': 0.37530306371635236, 'PnL': 6789.43673...
# 1  4002413037164645377  {'ROI': 2.492177630013404, 'PnL': 3686.9697606...
# 2  3923766029921022977  {'ROI': 0.15648862124032617, 'PnL': 772.729031...
# 3  3994879592543698688  {'ROI': 0.8283465412325384, 'PnL': 3658.765062...
# 4  3926423286576838657  {'ROI': 0.13545884037560071, 'PnL': 1309.45995...

# %%
# Define weights for each metric
weights = {
    'ROI': 0.30,
    'PnL': 0.25,
    'Sharpe Ratio': 0.20,
    'Max Drawdown': -0.15,  # Negative weight since lower drawdown is better
    'Win Rate': 0.10
}

# Function to calculate a composite score for each account
def calculate_score(metrics):
    score = (
        weights['ROI'] * metrics['ROI'] +
        weights['PnL'] * metrics['PnL'] +
        weights['Sharpe Ratio'] * metrics['Sharpe Ratio'] +
        weights['Max Drawdown'] * (100 - metrics['Max Drawdown']) +  # Invert drawdown
        weights['Win Rate'] * metrics['Win Rate']
    )
    return score

# Apply the score calculation
df_clean['Score'] = df_clean['Metrics'].apply(calculate_score)

# Rank the accounts by score
df_clean['Rank'] = df_clean['Score'].rank(ascending=False)

# Sort by rank and get the top 20 accounts
top_20_accounts = df_clean.sort_values(by='Score', ascending=False).head(20)

# Display the top 20 accounts
top_20_accounts[['Port_IDs', 'Metrics', 'Score', 'Rank']]
# Out:
#                 Port_IDs                                            Metrics  \
# 82   4020204877254599680  {'ROI': 0.3115608194225942, 'PnL': 71998.85595...
# 127  3999240873283311617  {'ROI': 0.5436734530219961, 'PnL': 42574.47367...
# 23   4021669203289716224  {'ROI': 0.4044195741684927, 'PnL': 26427.33159...
# 64   3960874214179953664  {'ROI': 0.23329625287420774, 'PnL': 19567.4712...
# 119  3907081197088384000  {'ROI': 1.0992418198530567, 'PnL': 18015.99737...
# 147  4028701921959171840  {'ROI': 0.40648048877447035, 'PnL': 17601.4013...
# 22   3956076827719377409  {'ROI': 1.032229831016538, 'PnL': 16790.012238...
# 35   3986814617275053313  {'ROI': 0.8716283426330235, 'PnL': 16337.46188...
# 68   3966142151544441601  {'ROI': 0.30386397204483057, 'PnL': 4883.80077...
# 87   4022565861939831809  {'ROI': 0.2330795004708387, 'PnL': 14197.57707...
# 43   3788465932399412480  {'ROI': 0.8368063722229295, 'PnL': 13960.96645...
# 5    3987739404272887297  {'ROI': 0.5570133876861003, 'PnL': 12464.60631...
# 107  4008711265867865600  {'ROI': 0.30824034145865814, 'PnL': 11298.7063...
# 60   3936410995029308417  {'ROI': 1.7910538387345112, 'PnL': 10681.514, ...
# 84   3931992636670880512  {'ROI': 0.571079625036539, 'PnL': 10374.965289...
# 75   3939318616482048768  {'ROI': 1.0162799258193562, 'PnL': 9775.389109...
# 25   3998572645139652353  {'ROI': 0.4680313781948754, 'PnL': 9603.585359...
# 108  3962024093501274881  {'ROI': 0.1459067814121951, 'PnL': 9314.494060...
# 57   4031493134338259457  {'ROI': 0.1158695729727135, 'PnL': 9082.698287...
# 139  4017263283405469185  {'ROI': 0.11458439798672428, 'PnL': 7141.36641...
#
#             Score  Rank
# 82   18108.509209   1.0
# 127  10634.924284   2.0
# 23    6597.525021   3.0
# 64    5400.161150   4.0
# 119   4499.269374   5.0
# 147   4391.714378   6.0
# 22    4191.796735   7.0
# 35    4077.709111   8.0
# 68    3932.127690   9.0
# 87    3541.494675  10.0
# 43    3483.360823  11.0
# 5     3108.289219  12.0
# 107   2814.904291  13.0
# 60    2659.034979  14.0
# 84    2589.385752  15.0
# 75    2433.296337  16.0
# 25    2390.915759  17.0
# 108   2329.561626  18.0
# 57    2273.738516  19.0
# 139   1962.099241  20.0

# %%
# Export metrics and scores to a CSV file
# Update this path to a valid directory on your machine
output_path = 'D:/Trade_data_analysis/top_accounts_metrics.csv'

# Save the DataFrame to the CSV file
df_clean.to_csv(output_path, index=False)

# Display the top 20 accounts
top_20_accounts_display = top_20_accounts[['Port_IDs', 'Metrics', 'Score', 'Rank']]
top_20_accounts_display
# Out:
#                 Port_IDs                                            Metrics  \
# 82   4020204877254599680  {'ROI': 0.3115608194225942, 'PnL': 71998.85595...
# 127  3999240873283311617  {'ROI': 0.5436734530219961, 'PnL': 42574.47367...
# 23   4021669203289716224  {'ROI': 0.4044195741684927, 'PnL': 26427.33159...
# 64   3960874214179953664  {'ROI': 0.23329625287420774, 'PnL': 19567.4712...
# 119  3907081197088384000  {'ROI': 1.0992418198530567, 'PnL': 18015.99737...
# 147  4028701921959171840  {'ROI': 0.40648048877447035, 'PnL': 17601.4013...
# 22   3956076827719377409  {'ROI': 1.032229831016538, 'PnL': 16790.012238...
# 35   3986814617275053313  {'ROI': 0.8716283426330235, 'PnL': 16337.46188...
# 68   3966142151544441601  {'ROI': 0.30386397204483057, 'PnL': 4883.80077...
# 87   4022565861939831809  {'ROI': 0.2330795004708387, 'PnL': 14197.57707...
# 43   3788465932399412480  {'ROI': 0.8368063722229295, 'PnL': 13960.96645...
# 5    3987739404272887297  {'ROI': 0.5570133876861003, 'PnL': 12464.60631...
# 107  4008711265867865600  {'ROI': 0.30824034145865814, 'PnL': 11298.7063...
# 60   3936410995029308417  {'ROI': 1.7910538387345112, 'PnL': 10681.514, ...
# 84   3931992636670880512  {'ROI': 0.571079625036539, 'PnL': 10374.965289...
# 75   3939318616482048768  {'ROI': 1.0162799258193562, 'PnL': 9775.389109...
# 25   3998572645139652353  {'ROI': 0.4680313781948754, 'PnL': 9603.585359...
# 108  3962024093501274881  {'ROI': 0.1459067814121951, 'PnL': 9314.494060...
# 57   4031493134338259457  {'ROI': 0.1158695729727135, 'PnL': 9082.698287...
# 139  4017263283405469185  {'ROI': 0.11458439798672428, 'PnL': 7141.36641...
#
#             Score  Rank
# 82   18108.509209   1.0
# 127  10634.924284   2.0
# 23    6597.525021   3.0
# 64    5400.161150   4.0
# 119   4499.269374   5.0
# 147   4391.714378   6.0
# 22    4191.796735   7.0
# 35    4077.709111   8.0
# 68    3932.127690   9.0
# 87    3541.494675  10.0
# 43    3483.360823  11.0
# 5     3108.289219  12.0
# 107   2814.904291  13.0
# 60    2659.034979  14.0
# 84    2589.385752  15.0
# 75    2433.296337  16.0
# 25    2390.915759  17.0
# 108   2329.561626  18.0
# 57    2273.738516  19.0
# 139   1962.099241  20.0

# %%
# Define the output path for the top 20 accounts
top_20_output_path = 'D:/Trade_data_analysis/top_20_accounts.csv'

# Save the top 20 accounts to a CSV file
top_20_accounts.to_csv(top_20_output_path, index=False)

print(f"Top 20 accounts have been saved to {top_20_output_path}.")
# Out:
# Top 20 accounts have been saved to D:/Trade_data_analysis/top_20_accounts.csv.
